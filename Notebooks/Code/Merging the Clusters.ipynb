# %%
import requests
import pandas as pd
import numpy as np
pd.set_option("display.max_columns", None)

# %%
df = pd.read_csv("/Users/aloaskari/Desktop/Ironhack/Bootcamp/Week_6/Song_recommender/Data/songs.csv")

df_clusters = pd.read_csv("/Users/aloaskari/Desktop/Ironhack/Bootcamp/Week_6/Song_recommender/Data/song_clusters.csv")

# %%
df.head()
# Out:
#    danceability  energy  key  loudness  mode  speechiness  acousticness  \
# 0         0.707   0.681    0    -4.325     1       0.0668        0.0632
# 1         0.347   0.378    8    -9.960     1       0.0354        0.8570
# 2         0.517   0.675    6    -5.382     1       0.0357        0.4590
# 3         0.714   0.472    2    -7.375     1       0.0864        0.0130
# 4         0.728   0.293    1   -13.657     0       0.0562        0.4790
#
#    instrumentalness  liveness  valence  ...            type  \
# 0          0.000005    0.0322    0.646  ...  audio_features
# 1          0.000000    0.1180    0.610  ...  audio_features
# 2          0.000000    0.1510    0.518  ...  audio_features
# 3          0.000005    0.2660    0.238  ...  audio_features
# 4          0.904000    0.1180    0.152  ...  audio_features
#
#                        id                                   uri  \
# 0  0yLdNVWF3Srea0uzk55zFn  spotify:track:0yLdNVWF3Srea0uzk55zFn
# ...

# %%
df_clusters.head()
# Out:
#    danceability  energy  loudness  speechiness  acousticness  \
# 0         0.707   0.681    -4.325       0.0668        0.0632
# 1         0.347   0.378    -9.960       0.0354        0.8570
# 2         0.517   0.675    -5.382       0.0357        0.4590
# 3         0.714   0.472    -7.375       0.0864        0.0130
# 4         0.728   0.293   -13.657       0.0562        0.4790
#
#    instrumentalness  liveness  valence    tempo  duration_ms  cluster
# 0          0.000005    0.0322    0.646  117.999       200455        2
# 1          0.000000    0.1180    0.610  173.482       168609        1
# 2          0.000000    0.1510    0.518  203.853       163855        0
# 3          0.000005    0.2660    0.238  131.121       156943        7
# 4          0.904000    0.1180    0.152   98.302       217026        3

# %%
df.columns
# Out:
# Index(['danceability', 'energy', 'key', 'loudness', 'mode', 'speechiness',
#        'acousticness', 'instrumentalness', 'liveness', 'valence', 'tempo',
#        'type', 'id', 'uri', 'track_href', 'analysis_url', 'duration_ms',
#        'time_signature', 'title', 'artist', 'hot_100'],
#       dtype='object')

# %%
df.dtypes
# Out:
# danceability        float64
# energy              float64
# key                   int64
# loudness            float64
# mode                  int64
# speechiness         float64
# acousticness        float64
# instrumentalness    float64
# liveness            float64
# valence             float64
# tempo               float64
# type                 object
# id                   object
# uri                  object
# track_href           object
# analysis_url         object
# duration_ms           int64
# time_signature        int64
# title                object
# artist               object
# hot_100               int64
# dtype: object

# %%
df_clusters.columns
# Out:
# Index(['danceability', 'energy', 'loudness', 'speechiness', 'acousticness',
#        'instrumentalness', 'liveness', 'valence', 'tempo', 'duration_ms',
#        'cluster'],
#       dtype='object')

# %%
df.dtypes
# Out:
# danceability        float64
# energy              float64
# key                   int64
# loudness            float64
# mode                  int64
# speechiness         float64
# acousticness        float64
# instrumentalness    float64
# liveness            float64
# valence             float64
# tempo               float64
# type                 object
# id                   object
# uri                  object
# track_href           object
# analysis_url         object
# duration_ms           int64
# time_signature        int64
# title                object
# artist               object
# hot_100               int64
# dtype: object

# %%
df_to_merge = df_clusters['cluster']

pd.DataFrame(df_to_merge)
# Out:
#       cluster
# 0           2
# 1           1
# 2           0
# 3           7
# 4           3
# ...       ...
# 2108        6
# 2109        1
# 2110        0
# 2111        0
# 2112        0
#
# [2113 rows x 1 columns]

# %%
merged_df = pd.merge(df, df_clusters[['duration_ms', 'cluster']], on='duration_ms', how='left')

merged_df
# Out:
#       danceability  energy  key  loudness  mode  speechiness  acousticness  \
# 0            0.707   0.681    0    -4.325     1       0.0668       0.06320
# 1            0.347   0.378    8    -9.960     1       0.0354       0.85700
# 2            0.517   0.675    6    -5.382     1       0.0357       0.45900
# 3            0.714   0.472    2    -7.375     1       0.0864       0.01300
# 4            0.728   0.293    1   -13.657     0       0.0562       0.47900
# ...            ...     ...  ...       ...   ...          ...           ...
# 2484         0.584   0.932    1    -3.501     1       0.3330       0.00106
# 2485         0.576   0.451    8    -9.571     1       0.0444       0.46900
# 2486         0.637   0.935    0    -2.467     1       0.1070       0.00857
# 2487         0.557   0.992    1    -2.735     1       0.1330       0.00164
# 2488         0.446   0.915    9    -6.221     1       0.1410       0.00281
#
# ...

# %%
merged_df.to_csv('songs_with_clusters.csv', index=False)

# %%
merged_df.dtypes
# Out:
# danceability        float64
# energy              float64
# key                   int64
# loudness            float64
# mode                  int64
# speechiness         float64
# acousticness        float64
# instrumentalness    float64
# liveness            float64
# valence             float64
# tempo               float64
# type                 object
# id                   object
# uri                  object
# track_href           object
# analysis_url         object
# duration_ms           int64
# time_signature        int64
# title                object
# artist               object
# hot_100               int64
# cluster               int64
# dtype: object
